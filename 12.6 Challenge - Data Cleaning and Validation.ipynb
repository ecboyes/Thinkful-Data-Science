# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sb
journals = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', engine = 'python', encoding = 'ISO-8859-1')

df = pd.DataFrame(journals)
print(df)
# Out:
#                        PMID/PMCID  \
# 0                             NaN
# 1                      PMC3785133
# 2        PMCID:\r    PMC3625741\r
# 3           23720616  PMC3654214
# 4                         3517619
# 5                             NaN
# 6                      PMC3443216
# 7                             NaN
# 8                        23239765
# 9                             NaN
# 10                        3498109
# 11                    PMC3739940
# 12                     PMC3557262
# 13              PMCID: PMC3559699
# 14                     PMC3694353
# 15              PMCID: PMC3502435
# 16             PMCID: PMC3491040
# 17         PMCID:\r    PMC3532161
# 18                        3515553
# 19                        3522679
# 20                            NaN
# 21                     PMC3474824
# 22           23805144 PMC3693486
# 23                 PMCID: 3507208
# 24                        3485223
# 25                       23166732
# ...

# %%
print(len(df.Publisher.unique()))
# Out:
# 295

# %%
# Stripping all spaces and beginning and end of each string
df['Publisher'] = df['Publisher'].str.strip()
df['PMID/PMCID'] = df['PMID/PMCID'].str.strip()

#print(len(df['Journal title'].unique()))
df['JournalTitle'] = df['Journal title'].str.strip()
print(len(df.JournalTitle.unique()))

df['Article title'] = df['Article title'].str.strip()
df['Cost'] = df['COST (£) charged to Wellcome (inc VAT when charged)'].str.strip()

df['Publisher'] = df.Publisher.str.title()
df['JournalTitle'] = df.JournalTitle.str.title()

print(len(df.Publisher.unique()))
df['Publisher'] = df['Publisher'].replace({'American Society For Biochemistry And Molecular Biolgy':'American Society For Biochemistry And Molecular Biology',
                                          'American Soc For Biochemistry And Molecular Biology':'American Society For Biochemistry And Molecular Biology',
                                          'American Society Of Haematology':'American Society Of Hematology',
                                          'American Society Of Hamatology':'American Society Of Hematology',
                                          'American Chemical Society':'American Chemical Society (ACS)',
                                          'Ambsb':'American Society For Biochemistry And Molecular Biology',
                                          'Asbmc /Cenveo':'American Society For Biochemistry And Molecular Biology',
                                          'The American Society For Biochemistry And Molecular Biology':'American Society For Biochemistry And Molecular Biology',
                                          'The American Society For Biochemistry And Molecular Biology, Inc':'American Society For Biochemistry And Molecular Biology',
                                          'American Society Of Microbiology':'American Society For Microbiology',
                                          'Asm':'American Society For Microbiology',
                                          'Asm (American Society For Microbiology)':'American Society For Microbiology',
                                          'Benthan Science Publishers':'Bentham Science Publishers',
                                          'Bmc':'BioMed Central',
                                          'British Medical Journal':'BMJ',
                                          'Byophysical Society':'Biophysical Society',
                                          'Cup':'Cambridge University Press',
                                          'Cshlp':'Cold Spring Harbor Laboratory Press',
                                          'Darmouth Journal Services':'Dartmouth Journal Services',
                                          'Dartmouth Journals':'Dartmouth Journal Services',
                                          'International Union Of Crystallography (Iucr)':'International Union Of Crystallography',
                                          'Lww':'Wolters Kluwer',
                                          'Federation Of The American Society Of Experimental Biology':'Federation Of American Societies For Experimental Biology',
                                          'Faseb':'Federation Of American Societies For Experimental Biology',
                                          'Npg':'Nature Publishing Group',
                                          'Society For Genermal Microbiology':'Society For General Microbiology',
                                          'Society For Neurosciences':'Society For Neuroscience',
                                          'Society Of Neuro Sciences':'Society For Neuroscience',
                                          'Society Of Neuroscience':'Society For Neuroscience',
                                          'T&F':'Taylor And Francis Group',
                                          'Oup':'Oxford University Press',
                                          'The Endrocrine Society':'The Endocrine Society',
                                          'Federation Of American Societies For Experimental Biology (Faseb)':'Federation Of American Societies For Experimental Biology'})


df.Publisher.unique()
# Out:
# 939
# 250
# array(['Cambridge University Press', 'Royal Society For Chemistry',
#        'Wiley', 'Frontiers', 'Plos', 'Public Library Of Science',
#        'Elsevier', 'Acs Publications', 'Frontiers Media Sa',
#        'The Company Of Biologists',
#        'American Society For Biochemistry And Molecular Biology',
#        'Cambridge Univ Press', 'Oxford University Press', 'Cadmus',
#        'Company Of Biologists', 'The Company Of Biolgists',
#        'Royal Society',
#        'Journal Of The American Physiological Proceedings Of National Academy Of Sciences',
#        'Plos (Public Library Of Science)', 'Nature',
#        'Nature Publishing Group', 'National Academy Of Sciences, Usa',
#        'Cold Spring Harbor Publications', 'Springer', 'BioMed Central',
#        'Springer Science + Business Media', 'Biomed Central Limited',
#        'Asbmb', 'Society For Endocrinology', 'The Sheridan Press',
#        'Biomed Central',
# ...

# %%
#word = 'Elsevier'
#list1=('Elseveier Science', 'Elsevier', 'Elsevier (Cell Press)',
#       'Elsevier / Cell Science', 'Elsevier B.V.', 'Elsevier Ltd',
#       'Elsevier/Cell Press')
#list2='Thinkful data science'
#def replaceString(word, replacement, strings):
#    for string in strings:
#        if word in string:
#            result = string.replace(string, replacement)
#        else:
#            return "" 
#    return result

#strings = df.Publisher.unique()

#print(strings)
#replaceString('Elsevier','replacement', list1)
#replaceString('Acs','American Chemical Society Publications',df.Publisher.unique())
#replaceString('Asbmb','American Society For Biochemistry And Molecular Biology',df.Publisher.unique())
#replaceString('Bmj','BMJ',df.Publisher.unique())
#replaceString('Biomed Central','BioMed Central',df.Publisher.unique())
#replaceString('Cold Spring','Cold Spring Harbor Laboratory Press',df.Publisher.unique())
#replaceString('Company Of Biologist','The Company Of Biologists',df.Publisher.unique())
#replaceString('Cambridge','Cambridge University Press',df.Publisher.unique())

# %%
import re

def replaceString(regex, fixed_string, single_string):
#    for string in strings:
    result = re.compile(regex,flags=re.I)
    if result.search(single_string):
        return fixed_string
    else:
        return single_string

def replaceStrings(regex, fixed_string, strings):
    strings_replaced = []
    for single_string in strings:
        strings_replaced.append(replaceString(regex, fixed_string, single_string))
    return strings_replaced
        
            
df['Actual Publishers'] = replaceStrings('.*Acs.*','American Chemical Society (ACS)',df.Publisher)
df['Actual Publishers'] = replaceStrings('.*American Psychiatric.*','American Psychiatric Association',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*American Physiological Society.*','American Physiological Society',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*American Chemical Society.*','American Chemical Society (ACS)',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Asbmb.*','American Society For Biochemistry And Molecular Biology',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Bmj.*','BMJ',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Biomed Central.*','BioMed Central',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Cadmus.*','Cenveo',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Cenveo.*','Cenveo',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Cold Spring.*','Cold Spring Harbor Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Cambridge.*','Cambridge University Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Company of Biologist.*','The Company of Biologists',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Frontiers.*','Frontiers Media',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*elsev.*','Elsevier',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Endocrine Soc.*','Endocrine Society',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Future.*','Future Science Group',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Hindawi.*','Hindawi Publishing Corporation',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Impact.*','Impact Journals',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Landes.*','Landes Bioscience',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Mary.*','Mary Ann Liebert, Inc',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Mit.*','MIT Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Open Access.*','MIT Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*National Academy.*','National Academy of Sciences',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Nature.*','Nature Publishing Group',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Informa.*','Informa Healthcare',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Jove.*','My Jove Corporation',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Oxford.*','Oxford University Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Public Library.*','Public Library Of Science',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Plos.*','Public Library Of Science',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Pnas.*','National Academy of Sciences',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Portland.*','Portland Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Royal Society.*','Royal Society of Chemistry',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Royal College Of Psychiatrists.*','Royal College Of Psychiatrists',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Rsc.*','Royal Society of Chemistry',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*sage.*','SAGE Publishing',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*pion.*','SAGE Publishing',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*pubmed.*','Pubmed',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Macmillan.*','Palgrave Macmillan',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Leukocyte.*','Society For Leukocyte Biology',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Francis.*','Taylor & Francis Group',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Springer.*','Springer Publishing',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Sheridan.*','Sheridan Press',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Society For Endocrinology.*','Society For Endocrinology',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Wiley.*','Wiley',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Blackwell.*','Wiley',df['Actual Publishers'])
df['Actual Publishers'] = replaceStrings('.*Wolters.*','Wolters Kluwer N.V.',df['Actual Publishers'])

print(df['Actual Publishers'].unique())
print(len(df['Actual Publishers'].unique()))
# Out:
# ['Cambridge University Press' 'Royal Society of Chemistry' 'Wiley'
#  'Frontiers Media' 'Public Library Of Science' 'Elsevier'
#  'American Chemical Society (ACS)' 'The Company of Biologists'
#  'American Society For Biochemistry And Molecular Biology'
#  'Oxford University Press' 'Cenveo' 'The Company Of Biolgists'
#  'National Academy of Sciences' 'Nature Publishing Group'
#  'Cold Spring Harbor Press' 'Springer Publishing' 'BioMed Central'
#  'Society For Endocrinology' 'Sheridan Press'
#  'Association For Research In Vision & Ophthalmology'
#  'Hindawi Publishing Corporation' 'Dartmouth Journal Services'
#  'Bioscientifica' 'American Society Of Hematology'
#  'American Society For Microbiology' 'BMJ'
#  'American Physiological Society' 'Mdpi' 'Impact Journals'
#  'J Med Internet Research' 'University Of The Basque Country Press'
#  'Palgrave Macmillan' 'Wolters Kluwer N.V.' 'Mary Ann Liebert, Inc'
#  'Sciedu Press' 'Coaction' 'Optical Society Of America'
# ...

# %%
print(df['Actual Publishers'].value_counts())
# Out:
# Elsevier                                                     399
# Public Library Of Science                                    286
# Wiley                                                        266
# Oxford University Press                                      164
# Springer Publishing                                           95
# BioMed Central                                                87
# Nature Publishing Group                                       78
# American Society For Biochemistry And Molecular Biology       72
# BMJ                                                           58
# National Academy of Sciences                                  35
# Royal Society of Chemistry                                    34
# American Chemical Society (ACS)                               34
# Cambridge University Press                                    31
# Frontiers Media                                               31
# ...

# %%
import re

def replaceString(regex, fixed_string, single_string):
#    for string in strings:
    result = re.compile(regex,flags=re.I)
    if result.search(str(single_string)):
        return fixed_string
    else:
        return single_string

def replaceStrings(regex, fixed_string, strings):
    strings_replaced = []
    for single_string in strings:
        strings_replaced.append(replaceString(regex, fixed_string, single_string))
    return strings_replaced

df['JournalTitle'].replace(to_replace='&', value='And', regex=True,inplace=True) 

df['Actual Journal Title'] = replaceStrings('.*J Med Chem.*','Journal Of Medicinal Chemistry',df.JournalTitle)
df['Actual Journal Title'] = replaceStrings('.*Journal Of Acquired Immune.*','Journal Of Acquired Immune Deficiency Syndromes',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Journal Of Aids.*','Journal Of Acquired Immune Deficiency Syndromes',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Aids Journal.*','Journal Of Acquired Immune Deficiency Syndromes',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Aids.*','Aids Uk',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Antimic.*','Antimicrobial Agents and Chemotherapy',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Antioxidants.*','Antioxidants and Redox Signaling',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Rheumatism.*','Arthritis & Rheumatism',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Biochemical Journal.*','Biochemical Journal',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*BBA.*','Biochimica et Biophysica Acta',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Biochimi.*','Biochimica et Biophysica Acta',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Bioinformatics Online.*','Bioinformatics',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Cell Death.*','Cell Death and Disease ',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Cerebral Cortex.*','Cerebral Cortex',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Clinical Infectious Diseases.*','Clinical Infectious Diseases',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*World Bioeth*','Developing World Bioethics',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Epigentics.*','Epigenetics',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*FEBS J.*','FEBS Journal',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Heptology.*','Hepatology',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Human Mol.*','Human Molecular Genetics Online',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*J Biol Chem.*','Journal Biological Chemistry',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Journal Of Biol Chem.*','Journal of Biological Chemistry',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Biologicial Chemistry.*','Journal of Biological Chemistry',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Biological Chemistry.*','Journal of Biological Chemistry',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Journal of Allergy.*','Journal of Allergy and Clinical Immunology',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Journal Of Neurophysiology.*','Journal Of Neurophysiology',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Bmc Genom.*','Bmc Genomics',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Neuroimage.*','NeuroImage',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Social Science & Medicine.*','Social Science And Medicine',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Lancet.*','The Lancet',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Faseb Journal.*','FASEB Journal',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Pnas.*','Proceedings Of The National Academy Of Sciences',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*National Academy Of Science.*','Proceedings Of The National Academy Of Sciences',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Brain Online.*','Brain',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Nucleic Acid Research.*','Nucleic Acids Research',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Plos 1.*','Plos One',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Plosone.*','Plos One',df['Actual Journal Title'])
df['Actual Journal Title'] = replaceStrings('.*Journal Of Neuroscience.*','Journal Of Neuroscience',df['Actual Journal Title'])



newList = df['Actual Journal Title'].unique()
newList.astype(str).sort()
print(len(newList))
print(newList)
# Out:
# 802
# ['Psychological Medicine' 'Chemical Communication'
#  'Arthritis & Rheumatism' 'Frontiers In Human Neuroscience' 'Plos One'
#  'NeuroImage' 'Plos' 'Movement Disorders' 'Journal Of Medicinal Chemistry'
#  'Frontiers In Immunology' 'Biol Open' 'Public Library Of Science'
#  'Frontiers In T Cell Biology' 'Journal of Biological Chemistry'
#  'Medical History' 'International Journal Of Law In Context'
#  'Cardiovascular Research' 'Biology Open' 'Development'
#  'Developmental Cell' 'Biinformatics'
#  'Proceedings Of The Royal Society B: Biological Sciences'
#  'Proceedings Of The National Academy Of Sciences'
#  'Public Library Of Science One' 'Neuropharmacology' 'Scientific Reports'
#  'Nature Scientific Reports' 'Sci Rep' 'Scientific Reports-11-00861B'
#  'Frontiers In Brain Imaging Methods' 'Rna' 'Plos Medicine' 'Urolithiasis'
#  'Malaria Journal' 'Springer Science + Business Media'
#  'Human Resources For Health' 'Bmc Health Services Research'
# ...

# %%
df.to_csv('Cleaned_Data.csv', encoding='utf-8')

# %%
print(df['Actual Journal Title'].value_counts())
# Out:
# Plos One                                                     198
# Journal of Biological Chemistry                               71
# Proceedings Of The National Academy Of Sciences               38
# NeuroImage                                                    34
# Nucleic Acids Research                                        29
# Plos Genetics                                                 22
# Human Molecular Genetics Online                               20
# Plos Neglected Tropical Diseases                              20
# Journal Of Neuroscience                                       19
# Brain                                                         18
# Nature Communications                                         18
# Plos Pathogens                                                16
# Aids Uk                                                       15
# Biochemical Journal                                           15
# ...

# %%
df['ActualJournalTitle'] = df['Actual Journal Title']
df['Cost'].replace(to_replace='$', value='', regex=False,inplace=True)
df['Cost'].replace(to_replace='£', value='', regex=True,inplace=True)
df['Cost_Numeric'] = df["Cost"].astype(np.float64)
groupedTitles = df.groupby(['Actual Journal Title'])

# %%
costSummary = groupedTitles.Cost_Numeric.describe()
costSummary.sort_values(by='count',ascending=False)
# Out:
#                                                     count          mean  \
# Actual Journal Title
# Plos One                                            198.0   1903.641212
# Journal of Biological Chemistry                      71.0   1378.140423
# Proceedings Of The National Academy Of Sciences      38.0    842.728421
# NeuroImage                                           34.0   2050.756176
# Nucleic Acids Research                               29.0   1162.344828
# Plos Genetics                                        22.0   1643.110909
# Human Molecular Genetics Online                      20.0   2023.937500
# Plos Neglected Tropical Diseases                     20.0   1563.519000
# Journal Of Neuroscience                              19.0   1871.287895
# Nature Communications                                18.0   3134.133333
# Brain                                                18.0   2100.000000
# Plos Pathogens                                       16.0   1590.933125
# ...
